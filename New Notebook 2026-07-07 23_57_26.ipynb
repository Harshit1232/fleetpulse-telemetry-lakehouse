# %%
spark.sql("DROP TABLE IF EXISTS fleetpulse.bronze.telemetry_raw")
spark.sql("DROP TABLE IF EXISTS fleetpulse.silver.telemetry_clean")
spark.sql("DROP TABLE IF EXISTS fleetpulse.silver.telemetry_quarantine")
dbutils.fs.rm("/Volumes/fleetpulse/raw/landing", recurse=True)
dbutils.fs.rm("/Volumes/fleetpulse/raw/checkpoints", recurse=True)

# %%
# print(dbutils.fs.ls("/Volumes/fleetpulse/raw/landing"))
print(dbutils.fs.ls("/Volumes/fleetpulse/raw/checkpoints"))
